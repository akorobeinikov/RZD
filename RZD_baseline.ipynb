# %% [markdown]
# ## Установка библиотек сегментации

# %%
# Catalyst
# !pip install catalyst==20.12

# for augmentations
# !pip install albumentations==0.4.3

# for pretrained segmentation models for PyTorch
# !pip install segmentation-models-pytorch==0.1.0

# for TTA
# !pip install ttach==0.0.2

# for tensorboard
# !pip install tensorflow

# if Your machine support Apex FP16, uncomment this 3 lines below
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
# is_fp16_used = True
# Out:
# ^C
# Requirement already satisfied: catalyst==20.12 in a:\rzd\rzd\lib\site-packages (20.12)
# Requirement already satisfied: numpy>=1.16.4 in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (1.21.6)
# Requirement already satisfied: PyYAML in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (6.0)
# Requirement already satisfied: tqdm>=4.33.0 in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (4.64.0)
# Requirement already satisfied: tensorboardX>=2.1.0 in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (2.5.1)
# Requirement already satisfied: packaging in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (21.3)
# Requirement already satisfied: torch>=1.1.0 in a:\rzd\rzd\lib\site-packages (from catalyst==20.12) (1.11.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in a:\rzd\rzd\lib\site-packages (from tensorboardX>=2.1.0->catalyst==20.12) (3.19.4)
# Requirement already satisfied: typing-extensions in a:\rzd\rzd\lib\site-packages (from torch>=1.1.0->catalyst==20.12) (4.2.0)
# Requirement already satisfied: colorama in a:\rzd\rzd\lib\site-packages (from tqdm>=4.33.0->catalyst==20.12) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in a:\rzd\rzd\lib\site-packages (from packaging->catalyst==20.12) (3.0.9)
# Requirement already satisfied: albumentations==0.4.3 in a:\rzd\rzd\lib\site-packages (0.4.3)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in a:\rzd\rzd\lib\site-packages (from albumentations==0.4.3) (4.6.0.66)
# Requirement already satisfied: imgaug<0.2.7,>=0.2.5 in a:\rzd\rzd\lib\site-packages (from albumentations==0.4.3) (0.2.6)
# Requirement already satisfied: scipy in a:\rzd\rzd\lib\site-packages (from albumentations==0.4.3) (1.7.3)
# Requirement already satisfied: numpy>=1.11.1 in a:\rzd\rzd\lib\site-packages (from albumentations==0.4.3) (1.21.6)
# Requirement already satisfied: PyYAML in a:\rzd\rzd\lib\site-packages (from albumentations==0.4.3) (6.0)
# Requirement already satisfied: six in a:\rzd\rzd\lib\site-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (1.16.0)
# Requirement already satisfied: scikit-image>=0.11.0 in a:\rzd\rzd\lib\site-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (0.19.3)
# Requirement already satisfied: packaging>=20.0 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in a:\rzd\rzd\lib\site-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (9.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in a:\rzd\rzd\lib\site-packages (from packaging>=20.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.3) (3.0.9)
# Requirement already satisfied: segmentation-models-pytorch==0.1.0 in a:\rzd\rzd\lib\site-packages (0.1.0)
# Requirement already satisfied: pretrainedmodels==0.7.4 in a:\rzd\rzd\lib\site-packages (from segmentation-models-pytorch==0.1.0) (0.7.4)
# Requirement already satisfied: torchvision>=0.3.0 in a:\rzd\rzd\lib\site-packages (from segmentation-models-pytorch==0.1.0) (0.12.0)
# Requirement already satisfied: efficientnet-pytorch>=0.5.1 in a:\rzd\rzd\lib\site-packages (from segmentation-models-pytorch==0.1.0) (0.7.1)
# Requirement already satisfied: torch in a:\rzd\rzd\lib\site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (1.11.0)
# Requirement already satisfied: munch in a:\rzd\rzd\lib\site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (2.5.0)
# Requirement already satisfied: tqdm in a:\rzd\rzd\lib\site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (4.64.0)
# Requirement already satisfied: typing-extensions in a:\rzd\rzd\lib\site-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in a:\rzd\rzd\lib\site-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (9.1.1)
# Requirement already satisfied: requests in a:\rzd\rzd\lib\site-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2.28.0)
# Requirement already satisfied: numpy in a:\rzd\rzd\lib\site-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (1.21.6)
# Requirement already satisfied: six in a:\rzd\rzd\lib\site-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in a:\rzd\rzd\lib\site-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in a:\rzd\rzd\lib\site-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in a:\rzd\rzd\lib\site-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\rzd\rzd\lib\site-packages (from requests->torchvision>=0.3.0->segmentation-models-pytorch==0.1.0) (1.26.9)
# Requirement already satisfied: colorama in a:\rzd\rzd\lib\site-packages (from tqdm->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.0) (0.4.5)
# Requirement already satisfied: ttach==0.0.2 in a:\rzd\rzd\lib\site-packages (0.0.2)
# Requirement already satisfied: tensorflow in a:\rzd\rzd\lib\site-packages (2.9.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in a:\rzd\rzd\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: six>=1.12.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: packaging in a:\rzd\rzd\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: libclang>=13.0.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in a:\rzd\rzd\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in a:\rzd\rzd\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in a:\rzd\rzd\lib\site-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in a:\rzd\rzd\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in a:\rzd\rzd\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in a:\rzd\rzd\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: flatbuffers<2,>=1.12 in a:\rzd\rzd\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: setuptools in a:\rzd\rzd\lib\site-packages (from tensorflow) (62.6.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in a:\rzd\rzd\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in a:\rzd\rzd\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.28.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in a:\rzd\rzd\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in a:\rzd\rzd\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in a:\rzd\rzd\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in a:\rzd\rzd\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in a:\rzd\rzd\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in a:\rzd\rzd\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in a:\rzd\rzd\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in a:\rzd\rzd\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in a:\rzd\rzd\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\rzd\rzd\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in a:\rzd\rzd\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: zipp>=0.5 in a:\rzd\rzd\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in a:\rzd\rzd\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in a:\rzd\rzd\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)

# %% [markdown]
# ## Настройка среды выполнения

# %%
from typing import Callable, List, Tuple

import os
import torch
import catalyst
from catalyst import utils

print(f"torch: {torch.__version__}, catalyst: {catalyst.__version__}")


SEED = 42
utils.set_global_seed(SEED)
utils.prepare_cudnn(deterministic=True)
# Out:
# torch: 1.11.0+cpu, catalyst: 20.12

# %% [markdown]
# ## Датасет
#
# Прежде чем разбираться с моделями, необходимо преобразовать начальный набор данных

# %%
from pathlib import Path

ROOT = Path("A:\RZD\data")

train_image_path = ROOT / "train\images"
train_mask_path = ROOT / "train\mask"
test_image_path = ROOT / "test"

# %% [markdown]
# Соберем маски и изображения вместе

# %%
ALL_IMAGES = sorted(train_image_path.glob("*.png"))
len(ALL_IMAGES)
# Out:
# 8203

# %%
ALL_MASKS = sorted(train_mask_path.glob("*.png"))
len(ALL_MASKS)
# Out:
# 8203

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread as gif_imread
from catalyst import utils
import cv2

def show_examples(name: str, image: np.ndarray, mask: np.ndarray):
    plt.figure(figsize=(10, 14))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title(f"Image: {name}")

    plt.subplot(1, 2, 2)
    plt.imshow(mask)
    plt.title(f"Mask: {name}")


def show(index: int, images: List[Path], masks: List[Path], transforms=None) -> None:
    image_path = images[index]
    name = image_path.name

    image = cv2.imread(str(image_path))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    mask = gif_imread(masks[index])
    mask[mask == 6] = 255
    mask[mask == 7] = 125
    mask[mask == 10] = 200

    if transforms is not None:
        print(image.shape, mask.shape)
        temp = transforms(image=image, mask=mask)
        image = temp["image"]
        mask = temp["mask"]

    show_examples(name, image, mask)

def show_random(images: List[Path], masks: List[Path], transforms=None) -> None:
    length = len(images)
    index = random.randint(0, length - 1)
    show(index, images, masks, transforms)

# %% [markdown]
# Посмотрим что у нас получилось

# %%
show_random(ALL_IMAGES, ALL_MASKS)

# %% [markdown]
# Приведенный ниже набор данных считывает изображения и маски и при необходимости применяет к ним увеличение.

# %%
from typing import List

from torch.utils.data import Dataset


class SegmentationDataset(Dataset):
    def __init__(
        self,
        images: List[Path],
        masks: List[Path] = None,
        transforms=None
    ) -> None:
        self.images = images
        self.masks = masks
        self.transforms = transforms

    def __len__(self) -> int:
        return len(self.images)

    def __getitem__(self, idx: int) -> dict:
        image_path = self.images[idx]
        image = cv2.imread(str(image_path))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        result = {"image": image}
        
        if self.masks is not None:
            mask = gif_imread(self.masks[idx])
            result["mask"] = mask
        
        if self.transforms is not None:
            result = self.transforms(**result)
        
        result["filename"] = image_path.name

        return result['image'], result['mask']

# %% [markdown]
# -------

# %% [markdown]
# ### Аугментация входных данных

# %%
import albumentations as albu
from albumentations.pytorch import ToTensor, ToTensorV2


def pre_transforms(image_size=224):
    return [albu.Resize(image_size, image_size, p=1)]


def hard_transforms():
    result = [
      albu.RandomRotate90(),
      albu.Cutout(),
      albu.RandomBrightnessContrast(
          brightness_limit=0.2, contrast_limit=0.2, p=0.3
      ),
      albu.GridDistortion(p=0.3),
      albu.HueSaturationValue(p=0.3)
    ]

    return result
  

def resize_transforms(image_size=224):
    BORDER_CONSTANT = 0
    pre_size = int(image_size * 1.5)

    random_crop = albu.Compose([
      albu.SmallestMaxSize(pre_size, p=1),
      albu.RandomCrop(
          image_size, image_size, p=1
      )

    ])

    rescale = albu.Compose([albu.Resize(image_size, image_size, p=1)])

    random_crop_big = albu.Compose([
      albu.LongestMaxSize(pre_size, p=1),
      albu.RandomCrop(
          image_size, image_size, p=1
      )

    ])

    # Converts the image to a square of size image_size x image_size
    result = [
      albu.OneOf([
          random_crop,
          rescale,
#           random_crop_big
      ], p=1)
    ]

    return result

def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return _transform

def post_transforms():
    # we use ImageNet image normalization
    # and convert it to torch.Tensor
    return [albu.Normalize(), ToTensor()]
  
def compose(transforms_to_compose):
    # combine all augmentations into single pipeline
    result = albu.Compose([
      item for sublist in transforms_to_compose for item in sublist
    ])
    return result

# %%
show_transforms = compose([resize_transforms(), hard_transforms()])

# %% [markdown]
# Взглянем на полученный результат

# %%
show_random(ALL_IMAGES, ALL_MASKS, transforms=show_transforms)
# Out:
# (1512, 2688, 3) (1512, 2688, 3)

# %% [markdown]
# -------

# %% [markdown]
# ## Загрузка

# %%
import collections
from sklearn.model_selection import train_test_split

from torch.utils.data import DataLoader

def get_loaders(
    images: List[Path],
    masks: List[Path],
    random_state: int,
    valid_size: float = 0.5,
    batch_size: int = 32,
    num_workers: int = 0,
    train_transforms_fn = None,
    valid_transforms_fn = None,
) -> dict:

    indices = np.arange(len(images))

    # Let's divide the data set into train and valid parts.
    train_indices, valid_indices = train_test_split(
      indices, test_size=valid_size, random_state=random_state, shuffle=True
    )

    np_images = np.array(images)
    np_masks = np.array(masks)

    # Creates our train dataset
    train_dataset = SegmentationDataset(
      images = np_images[train_indices].tolist(),
      masks = np_masks[train_indices].tolist(),
      transforms = train_transforms_fn
    )

    # Creates our valid dataset
    valid_dataset = SegmentationDataset(
      images = np_images[valid_indices].tolist(),
      masks = np_masks[valid_indices].tolist(),
      transforms = valid_transforms_fn
    )

    # Catalyst uses normal torch.data.DataLoader
    train_loader = DataLoader(
      train_dataset,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      drop_last=True,
    )

    valid_loader = DataLoader(
      valid_dataset,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      drop_last=True,
    )

    # And excpect to get an OrderedDict of loaders
    loaders = collections.OrderedDict()
    loaders["train"] = train_loader
    loaders["valid"] = valid_loader

    return loaders

# %% [markdown]
# -------

# %% [markdown]
# ## Настройка параметров модели
# Библиотека Catalyst имеет несколько моделей у себя на борту (Unet, Linknet, FPN, PSPnet and their versions with pretrain from Resnet).
#
# Но в примере будет расмотрена (SMP for short).

# %%
import segmentation_models_pytorch as smp

# We will use Feature Pyramid Network with pre-trained ResNeXt50 backbone
ENCODER="resnext50_32x4d"
smp.FPN()
model = smp.FPN(encoder_name=ENCODER, encoder_weights='imagenet', in_channels=3, classes=3, activation='softmax2d')
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, 'imagenet')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to C:\Users\aalle/.cache\torch\hub\checkpoints\resnet34-333f7ec4.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 83.3M/83.3M [00:22<00:00, 3.94MB/s]

# %%
train_transforms = compose([
    resize_transforms(), 
    hard_transforms(), 
    get_preprocessing(preprocessing_fn)
])
valid_transforms = compose([pre_transforms(), get_preprocessing(preprocessing_fn)])

# %%
batch_size = 32

print(f"batch_size: {batch_size}")

loaders = get_loaders(
    images=ALL_IMAGES,
    masks=ALL_MASKS,
    random_state=SEED,
    train_transforms_fn=train_transforms,
    valid_transforms_fn=valid_transforms,
    batch_size=batch_size
)
# Out:
# batch_size: 32

# %% [markdown]
# ### Обучение модели 1
#
# We will optimize Dice loss.

# %%
loss = smp.utils.losses.DiceLoss(eps=1.)
metrics = [
    smp.utils.metrics.IoU(eps=1., activation='softmax2d'),
]

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0001),
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device='cpu',
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device='cpu',
    verbose=True,
)

# train model for 3 epochs

max_score = 0

for i in range(0, 3):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(loaders['train'])
    valid_logs = valid_epoch.run(loaders['valid'])
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, './best_model.pth')
        print('Model saved!')
        
    if i == 25:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5!')
# Out:
# Epoch: 0
# train:  64%|█████████████████████▊            | 82/128 [50:29<28:19, 36.94s/it, dice_loss - 0.4899, iou_score - 0.2048]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5952\3106618761.py in <module>
#      25
#      26     print('\nEpoch: {}'.format(i))
# ---> 27     train_logs = train_epoch.run(loaders['train'])
#      28     valid_logs = valid_epoch.run(loaders['valid'])
#      29
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\utils\train.py in run(self, dataloader)
#      45             for x, y in iterator:
#      46                 x, y = x.to(self.device), y.to(self.device)
# ---> 47                 loss, y_pred = self.batch_update(x, y)
#      48
#      49                 # update loss logs
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\utils\train.py in batch_update(self, x, y)
#      85     def batch_update(self, x, y):
#      86         self.optimizer.zero_grad()
# ---> 87         prediction = self.model.forward(x)
#      88         loss = self.loss(prediction, y)
#      89         loss.backward()
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\base\model.py in forward(self, x)
#      14         """Sequentially pass `x` trough model`s encoder, decoder and heads"""
#      15         features = self.encoder(x)
# ---> 16         decoder_output = self.decoder(*features)
#      17
#      18         masks = self.segmentation_head(decoder_output)
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\fpn\decoder.py in forward(self, *features)
#     113         p2 = self.p2(p3, c2)
#     114
# --> 115         feature_pyramid = [seg_block(p) for seg_block, p in zip(self.seg_blocks, [p5, p4, p3, p2])]
#     116         x = self.merge(feature_pyramid)
#     117         x = self.dropout(x)
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\fpn\decoder.py in <listcomp>(.0)
#     113         p2 = self.p2(p3, c2)
#     114
# --> 115         feature_pyramid = [seg_block(p) for seg_block, p in zip(self.seg_blocks, [p5, p4, p3, p2])]
#     116         x = self.merge(feature_pyramid)
#     117         x = self.dropout(x)
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\fpn\decoder.py in forward(self, x)
#      48
#      49     def forward(self, x):
# ---> 50         return self.block(x)
#      51
#      52
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\segmentation_models_pytorch\fpn\decoder.py in forward(self, x)
#      17
#      18     def forward(self, x):
# ---> 19         x = self.block(x)
#      20         if self.upsample:
#      21             x = F.interpolate(x, scale_factor=2, mode="bilinear", align_corners=True)
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
# --> 447         return self._conv_forward(input, self.weight, self.bias)
#     448
#     449 class Conv3d(_ConvNd):
#
# a:\rzd\rzd\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     442                             _pair(0), self.dilation, self.groups)
#     443         return F.conv2d(input, weight, bias, self.stride,
# --> 444                         self.padding, self.dilation, self.groups)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Обучение модели 2
#
# We will optimize loss as the sum of IoU, Dice and BCE, specifically this function: $IoU + Dice + 0.8*BCE$.

# %%
from torch import nn

from catalyst.contrib.nn import DiceLoss, IoULoss

# we have multiple criterions
criterion = {
    "dice": DiceLoss(),
    "iou": IoULoss(),
    "bce": nn.BCEWithLogitsLoss()
}

# %%
from torch import optim

from catalyst.contrib.nn import RAdam, Lookahead

learning_rate = 0.001
encoder_learning_rate = 0.0005

# Since we use a pre-trained encoder, we will reduce the learning rate on it.
layerwise_params = {"encoder*": dict(lr=encoder_learning_rate, weight_decay=0.00003)}

# This function removes weight_decay for biases and applies our layerwise_params
model_params = utils.process_model_params(model, layerwise_params=layerwise_params)

# Catalyst has new SOTA optimizers out of box
base_optimizer = RAdam(model_params, lr=learning_rate, weight_decay=0.0003)
optimizer = Lookahead(base_optimizer)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.25, patience=2)

# %%
from catalyst.dl import SupervisedRunner

num_epochs = 3
logdir = "./logs/segmentation"

device = utils.get_device()
print(f"device: {device}")

#fp16_params = dict(opt_level="O1") # params for FP16
fp16_params = None

print(f"FP16 params: {fp16_params}")


# by default SupervisedRunner uses "features" and "targets",
# in our case we get "image" and "mask" keys in dataset __getitem__
runner = SupervisedRunner(device=device, input_key="image", input_target_key="mask")
# Out:
# device: cpu
# FP16 params: None

# %% [markdown]
# ### Запустим обучение

# %%
from catalyst.dl import DiceCallback, IouCallback, \
  CriterionCallback, MetricAggregationCallback
from catalyst.contrib.callbacks import DrawMasksCallback

callbacks = [
    # Each criterion is calculated separately.
    CriterionCallback(
        input_key="mask",
        prefix="loss_dice",
        criterion_key="dice"
    ),
    CriterionCallback(
        input_key="mask",
        prefix="loss_iou",
        criterion_key="iou"
    ),
    CriterionCallback(
        input_key="mask",
        prefix="loss_bce",
        criterion_key="bce"
    ),

    # And only then we aggregate everything into one loss.
    MetricAggregationCallback(
        prefix="loss",
        mode="weighted_sum", # can be "sum", "weighted_sum" or "mean"
        # because we want weighted sum, we need to add scale for each loss
        metrics={"loss_dice": 1.0, "loss_iou": 1.0, "loss_bce": 0.8},
    ),

    # metrics
    DiceCallback(input_key="mask"),
    IouCallback(input_key="mask"),
    # visualization
    DrawMasksCallback(output_key='logits',
                      input_image_key='image',
                      input_mask_key='mask',
                      summary_step=50
    )
]

runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    # our dataloaders
    loaders=loaders,
    # We can specify the callbacks list for the experiment;
    callbacks=callbacks,
    # path to save logs
    logdir=logdir,
    num_epochs=num_epochs,
    # save our best checkpoint by IoU metric
    main_metric="iou",
    # IoU needs to be maximized.
    minimize_metric=False,
    # for FP16. It uses the variable from the very first cell
    fp16=fp16_params,
    # prints train logs
    verbose=True,
)
# Out:
# 1/3 * Epoch (train):   0% 0/128 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25304\2792073145.py in <module>
#      59     fp16=fp16_params,
#      60     # prints train logs
# ---> 61     verbose=True,
#      62 )
#
# a:\rzd\rzd\lib\site-packages\catalyst\runners\runner.py in train(self, model, criterion, optimizer, scheduler, datasets, loaders, callbacks, logdir, resume, num_epochs, valid_loader, main_metric, minimize_metric, verbose, stage_kwargs, checkpoint_data, fp16, distributed, check, overfit, timeit, load_best_on_end, initial_seed, state_kwargs)
#     212         )
#     213         self.experiment = experiment
# --> 214         distributed_cmd_run(self.run_experiment, distributed)
#     215
#     216     def infer(
#
# a:\rzd\rzd\lib\site-packages\catalyst\utils\scripts.py in distributed_cmd_run(worker_fn, distributed, *args, **kwargs)
#     176         or world_size <= 1
#     177     ):
# --> 178         worker_fn(*args, **kwargs)
#     179     elif local_rank is not None:
#     180         torch.cuda.set_device(int(local_rank))
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in run_experiment(self, experiment)
#     827         except (Exception, KeyboardInterrupt) as ex:
#     828             self.exception = ex
# --> 829             self._run_event("on_exception")
#     830         return self
#     831
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in _run_event(self, event)
#     756             getattr(self, event)(self)
#     757         for callback in self.callbacks.values():
# --> 758             getattr(callback, event)(self)
#     759         if _is_substring(event, ("end",)):
#     760             getattr(self, event)(self)
#
# a:\rzd\rzd\lib\site-packages\catalyst\callbacks\exception.py in on_exception(self, runner)
#      32
#      33         if runner.need_exception_reraise:
# ---> 34             raise exception
#      35
#      36
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in run_experiment(self, experiment)
#     824         self.experiment = experiment or self.experiment
#     825         try:
# --> 826             self._run_experiment()
#     827         except (Exception, KeyboardInterrupt) as ex:
#     828             self.exception = ex
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in _run_experiment(self)
#     809         self._run_event("on_experiment_start")
#     810         for self.stage in self.experiment.stages:
# --> 811             self._run_stage()
#     812         self._run_event("on_experiment_end")
#     813
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in _run_stage(self)
#     800         self._run_event("on_stage_start")
#     801         while self.epoch < self.num_epochs + 1:
# --> 802             self._run_epoch()
#     803             if self.need_early_stop:
#     804                 self.need_early_stop = False
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in _run_epoch(self)
#     794         self._run_event("on_epoch_start")
#     795         for self.loader_key, self.loader in self.loaders.items():
# --> 796             self._run_loader()
#     797         self._run_event("on_epoch_end")
#     798
#
# a:\rzd\rzd\lib\site-packages\catalyst\core\runner.py in _run_loader(self)
#     784         self._run_event("on_loader_start")
#     785         with torch.set_grad_enabled(self.is_train_loader):
# --> 786             for self.loader_batch_step, self.input in enumerate(self.loader):
#     787                 self._run_batch()
#     788                 if self.need_early_stop:
#
# a:\rzd\rzd\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     366             return self._iterator
#     367         else:
# --> 368             return self._get_iterator()
#     369
#     370     @property
#
# a:\rzd\rzd\lib\site-packages\torch\utils\data\dataloader.py in _get_iterator(self)
#     312         else:
#     313             self.check_worker_number_rationality()
# --> 314             return _MultiProcessingDataLoaderIter(self)
#     315
#     316     @property
#
# a:\rzd\rzd\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     925             #     before it starts, and __del__ tries to join but will get:
#     926             #     AssertionError: can only join a started process.
# --> 927             w.start()
#     928             self._index_queues.append(index_queue)
#     929             self._workers.append(w)
#
# A:\Anaconda3\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# A:\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# A:\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# A:\Anaconda3\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      87             try:
#      88                 reduction.dump(prep_data, to_child)
# ---> 89                 reduction.dump(process_obj, to_child)
#      90             finally:
#      91                 set_spawning_popen(None)
#
# A:\Anaconda3\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ## Проверка модели
#
# Давайте посмотрим на прогнозы модели.

# %%
TEST_IMAGES = sorted(test_image_path.glob("*.png"))

# create test dataset
test_dataset = SegmentationDataset(
    TEST_IMAGES, 
    transforms=valid_transforms
)

num_workers: int = 4

infer_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers
)

# this get predictions for the whole loader
predictions = np.vstack(list(map(
    lambda x: x["logits"].cpu().numpy(), 
    runner.predict_loader(loader=infer_loader, resume=f"{logdir}/checkpoints/best.pth")
)))

print(type(predictions))
print(predictions.shape)

# %%
threshold = 0.5
max_count = 5

for i, (features, logits) in enumerate(zip(test_dataset, predictions)):
    image = utils.tensor_to_ndimage(features["image"])

    mask_ = torch.from_numpy(logits[0]).sigmoid()
    mask = utils.detach(mask_ > threshold).astype("float")
        
    show_examples(name="", image=image, mask=mask)
    
    if i >= max_count:
        break
